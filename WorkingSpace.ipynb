# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt
#
# import sys
# sys.path.insert(0, './')
#
# # class de travail
# from Python.automaticImageIndexing import AutomaticImageIndexing
# automaticImageIndexing = AutomaticImageIndexing()
#
# print(''.join(['Version : ', automaticImageIndexing.version()]))
# print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))
#
# automaticImageIndexing.n_limite_directories = 20
# automaticImageIndexing.n_limite_images = 2
# print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
# print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))
#
# automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
# automaticImageIndexing.annotation_directory = 'annotation/'
# automaticImageIndexing.picture_directory = 'images/'
#
# automaticImageIndexing.read_picture_and_shift_feature_generation()
#
# #
# automaticImageIndexing.n_clusters = 100
# automaticImageIndexing.n_vocables = 8
# dic = range(automaticImageIndexing.n_vocables)
#
# automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)
#
# #représenter 1 cluster pour voir l'homogénéité?
# #=>représentation des descriptor du cluster
#
# mega_histo = automaticImageIndexing.developBagOfVisualWord(automaticImageIndexing.n_vocables)
#
# #fonction d'application de developvoca.. pour une image (nb cluster variable)
# #trouver l'optimal perf / justesse
# #tester par espèce
# # visuel
# # montrer des correspondance
#
# automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)
#
# mega_histo = automaticImageIndexing.standardize(mega_histo)
# model_predition =automaticImageIndexing.train(mega_histo, dic)

# %% [markdown]
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
#     True
# )
#
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
#     True
# )
#
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
#     True
# )

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

# class de travail
from Python.automaticImageIndexing import AutomaticImageIndexing
automaticImageIndexing = AutomaticImageIndexing()

print(''.join(['Version : ', automaticImageIndexing.version()]))
print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

automaticImageIndexing.n_limite_directories = 1#3
automaticImageIndexing.n_limite_images = 1#0
print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
automaticImageIndexing.annotation_directory = 'annotation/'
automaticImageIndexing.picture_directory = 'images/'

automaticImageIndexing.read_picture_and_shift_feature_generation(True)

automaticImageIndexing.n_clusters = 2

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

#représenter 1 cluster pour voir l'homogénéité?
#=>représentation des descriptor du cluster

mega_histo = automaticImageIndexing.developBagOfVisualWord()#automaticImageIndexing.n_vocables)

#fonction d'application de developvoca.. pour une image (nb cluster variable)
#trouver l'optimal perf / justesse 
#tester par espèce 
# visuel
# montrer des correspondance

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)

print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)

print("cluster 1")
automaticImageIndexing.plot_descriptor_in_cluster(1)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)
# Out:
# Version : 0.2
# Data directory : Data/
# Max Number of directory : 1
# Max Number of picture by directory : 1
# Computing Features for  n02085620-Chihuahua
# generate subpicture
# <generator object <genexpr> at 0x00000000283547E0>
# Vocabulary Histogram Generated
# Plotting histogram
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-65cf8cc32557> in <module>()
#      43 mega_histo = automaticImageIndexing.standardize(mega_histo)
#      44 id_label = range(len(automaticImageIndexing.name_dict))
# ---> 45 model_predition =automaticImageIndexing.train(mega_histo, id_label)
#      46
#      47 print("cluster 0")
#
# C:\Users\naru_\Documents\Projet7_ImageIndex\Source\AutomaticImageIndexing\Python\automaticImageIndexing.py in train(self, mega_histogram, train_labels)
#     499         uses sklearn.svm.SVC classifier (SVM)
#     500         """
# --> 501         self.clf.fit(mega_histogram, train_labels)
#     502         print "Training completed"
#     503
#
# C:\Users\naru_\Anaconda3\envs\opencv2\lib\site-packages\sklearn\svm\base.pyc in fit(self, X, y, sample_weight)
#     148                          order='C', accept_sparse='csr',
#     149                          accept_large_sparse=False)
# --> 150         y = self._validate_targets(y)
#     151
#     152         sample_weight = np.asarray([]
#
# C:\Users\naru_\Anaconda3\envs\opencv2\lib\site-packages\sklearn\svm\base.pyc in _validate_targets(self, y)
#     523             raise ValueError(
#     524                 "The number of classes has to be greater than one; got %d"
# --> 525                 " class" % len(cls))
#     526
#     527         self.classes_ = cls
#
# ValueError: The number of classes has to be greater than one; got 1 class

# %%
automaticImageIndexing.sub_picture_list[5]
# Out:
# array([[[ 33,  31,  51],
#         [ 31,  29,  49],
#         [ 29,  27,  47],
#         [ 25,  24,  44],
#         [ 21,  22,  42],
#         [ 19,  20,  40],
#         [ 24,  28,  47],
#         [ 23,  29,  48],
#         [ 23,  29,  48],
#         [ 21,  28,  47],
#         [ 19,  26,  45]],
#
#        [[ 31,  29,  51],
#         [ 29,  30,  51],
#         [ 29,  30,  51],
#         [ 26,  29,  50],
#         [ 23,  28,  49],
#         [ 22,  27,  48],
#         [ 24,  31,  51],
#         [ 23,  32,  52],
#         [ 25,  34,  54],
#         [ 24,  35,  55],
#         [ 23,  34,  54]],
#
#        [[ 34,  37,  58],
#         [ 36,  41,  62],
#         [ 39,  44,  65],
#         [ 40,  47,  67],
#         [ 39,  48,  68],
#         [ 37,  48,  68],
#         [ 20,  34,  53],
#         [ 21,  36,  55],
#         [ 25,  40,  59],
#         [ 26,  43,  62],
#         [ 26,  46,  64]],
#
#        [[ 22,  33,  55],
#         [ 13,  26,  48],
#         [ 43,  56,  78],
#         [ 58,  72,  94],
#         [ 62,  79, 100],
#         [ 85, 104, 125],
#         [108, 129, 150],
#         [ 99, 123, 143],
#         [ 82, 106, 126],
#         [ 83, 108, 128],
#         [ 93, 120, 140]],
#
#        [[ 12,  29,  50],
#         [ 35,  54,  75],
#         [101, 120, 141],
#         [139, 160, 181],
#         [155, 179, 199],
#         [184, 208, 228],
#         [178, 203, 223],
#         [185, 212, 232],
#         [178, 208, 227],
#         [171, 201, 220],
#         [176, 208, 227]],
#
#        [[137, 161, 181],
#         [170, 195, 215],
#         [200, 225, 245],
#         [196, 221, 241],
#         [174, 201, 221],
#         [174, 201, 221],
#         [158, 188, 207],
#         [162, 194, 213],
#         [165, 198, 217],
#         [155, 188, 207],
#         [145, 178, 197]],
#
#        [[193, 220, 240],
#         [197, 224, 244],
#         [193, 220, 240],
#         [188, 215, 235],
#         [176, 206, 225],
#         [174, 204, 223],
#         [154, 184, 203],
#         [143, 175, 194],
#         [155, 188, 207],
#         [157, 190, 209],
#         [128, 161, 180]],
#
#        [[189, 216, 237],
#         [162, 189, 210],
#         [145, 172, 193],
#         [135, 162, 183],
#         [128, 155, 176],
#         [125, 152, 173],
#         [137, 164, 185],
#         [124, 153, 174],
#         [140, 169, 190],
#         [148, 179, 200],
#         [124, 155, 176]],
#
#        [[154, 178, 200],
#         [156, 183, 204],
#         [152, 176, 198],
#         [130, 154, 176],
#         [116, 140, 162],
#         [118, 142, 164],
#         [127, 151, 173],
#         [122, 146, 168],
#         [117, 144, 165],
#         [115, 142, 163],
#         [117, 144, 165]],
#
#        [[132, 155, 177],
#         [128, 152, 174],
#         [119, 142, 164],
#         [109, 132, 154],
#         [109, 132, 154],
#         [109, 132, 154],
#         [120, 143, 165],
#         [118, 141, 163],
#         [101, 122, 144],
#         [ 89, 110, 132],
#         [102, 123, 145]],
#
#        [[137, 161, 183],
#         [109, 133, 153],
#         [100, 124, 144],
#         [123, 144, 165],
#         [122, 143, 164],
#         [ 94, 113, 134],
#         [123, 142, 163],
#         [125, 144, 165],
#         [112, 131, 152],
#         [106, 125, 146],
#         [104, 123, 144]]], dtype=uint8)

# %%
print(len([ num for num in automaticImageIndexing.kmeans_ret if num == 0 ]))
print(len([ num for num in automaticImageIndexing.kmeans_ret if num == 1 ]))

#ajouter des notion de calcul d'estimation de temps d'exec
#1 image => 10 minutes
#2000 image => ?

# 10 descripteurs au hazard pour des centroides intéressants
#=> distance euclidienne pour les images?

#prediction suite a representation en BOV
# Out:
# 454
# 366

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

# class de travail
from Python.automaticImageIndexing import AutomaticImageIndexing
automaticImageIndexing = AutomaticImageIndexing()

print(''.join(['Version : ', automaticImageIndexing.version()]))
print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

automaticImageIndexing.n_limite_directories = 3
automaticImageIndexing.n_limite_images = 0
print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
automaticImageIndexing.annotation_directory = 'annotation/'
automaticImageIndexing.picture_directory = 'images/'

automaticImageIndexing.read_picture_and_shift_feature_generation(False)

automaticImageIndexing.n_clusters = 50

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

#représenter 1 cluster pour voir l'homogénéité?
#=>représentation des descriptor du cluster

mega_histo = automaticImageIndexing.developBagOfVisualWord()#automaticImageIndexing.n_vocables)

#fonction d'application de developvoca.. pour une image (nb cluster variable)
#trouver l'optimal perf / justesse 
#tester par espèce 
# visuel
# montrer des correspondance

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)

print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)

print("cluster 1")
automaticImageIndexing.plot_descriptor_in_cluster(1)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)

# %%
automaticImageIndexing.n_clusters = 100

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

mega_histo = automaticImageIndexing.developBagOfVisualWord()

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)


print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)

print("cluster 1")
automaticImageIndexing.plot_descriptor_in_cluster(1)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)

# %%
automaticImageIndexing.n_clusters = 200

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

mega_histo = automaticImageIndexing.developBagOfVisualWord()

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)

print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)

print("cluster 1")
automaticImageIndexing.plot_descriptor_in_cluster(1)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)

# %% [markdown]
# automaticImageIndexing.n_clusters = 20
#
# automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)
#
# mega_histo = automaticImageIndexing.developBagOfVisualWord()
#
# automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)
#
# mega_histo = automaticImageIndexing.standardize(mega_histo)
# id_label = range(len(automaticImageIndexing.name_dict))
# model_predition =automaticImageIndexing.train(mega_histo, id_label)
#
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
#     True
# )
#
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
#     True
# )
#
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
#     True
# )
#
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
#     True
# )

# %% [markdown]
# automaticImageIndexing.n_clusters = 10
#
# automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)
#
# mega_histo = automaticImageIndexing.developBagOfVisualWord()
#
# automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)
#
# mega_histo = automaticImageIndexing.standardize(mega_histo)
# id_label = range(len(automaticImageIndexing.name_dict))
# model_predition =automaticImageIndexing.train(mega_histo, id_label)
#
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
#     True
# )
#
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
#     True
# )
#
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
#     True
# )
#
# picture_histogramme = automaticImageIndexing.picture_in_BOV(
#     r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
#     True
# )

# %%
automaticImageIndexing.n_clusters = 500

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

mega_histo = automaticImageIndexing.developBagOfVisualWord()

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)


print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)

print("cluster 1")
automaticImageIndexing.plot_descriptor_in_cluster(1)


picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

# class de travail
from Python.automaticImageIndexing import AutomaticImageIndexing
automaticImageIndexing = AutomaticImageIndexing()

print(''.join(['Version : ', automaticImageIndexing.version()]))
print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

automaticImageIndexing.n_limite_directories = 5
automaticImageIndexing.n_limite_images = 0
print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
automaticImageIndexing.annotation_directory = 'annotation/'
automaticImageIndexing.picture_directory = 'images/'

automaticImageIndexing.read_picture_and_shift_feature_generation(False)

automaticImageIndexing.n_clusters = 100

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

#représenter 1 cluster pour voir l'homogénéité?
#=>représentation des descriptor du cluster

mega_histo = automaticImageIndexing.developBagOfVisualWord()#automaticImageIndexing.n_vocables)

#fonction d'application de developvoca.. pour une image (nb cluster variable)
#trouver l'optimal perf / justesse 
#tester par espèce 
# visuel
# montrer des correspondance

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)

print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)


picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

# class de travail
from Python.automaticImageIndexing import AutomaticImageIndexing
automaticImageIndexing = AutomaticImageIndexing()

print(''.join(['Version : ', automaticImageIndexing.version()]))
print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

automaticImageIndexing.n_limite_directories = 10
automaticImageIndexing.n_limite_images = 0
print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
automaticImageIndexing.annotation_directory = 'annotation/'
automaticImageIndexing.picture_directory = 'images/'

automaticImageIndexing.read_picture_and_shift_feature_generation(False)

automaticImageIndexing.n_clusters = 100

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

#représenter 1 cluster pour voir l'homogénéité?
#=>représentation des descriptor du cluster

mega_histo = automaticImageIndexing.developBagOfVisualWord()#automaticImageIndexing.n_vocables)

#fonction d'application de developvoca.. pour une image (nb cluster variable)
#trouver l'optimal perf / justesse 
#tester par espèce 
# visuel
# montrer des correspondance

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)

print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)


picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)
# Out:
# Version : 0.2
# Data directory : Data/
# Max Number of directory : 10
# Max Number of picture by directory : 0
# Computing Features for  n02085620-Chihuahua
# Computing Features for  n02085782-Japanese_spaniel
# Computing Features for  n02085936-Maltese_dog
# Computing Features for  n02086079-Pekinese
# Computing Features for  n02086240-Shih-Tzu
# Computing Features for  n02086646-Blenheim_spaniel
# Computing Features for  n02086910-papillon
# Computing Features for  n02087046-toy_terrier
# Computing Features for  n02087394-Rhodesian_ridgeback
# Computing Features for  n02088094-Afghan_hound

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

# class de travail
from Python.automaticImageIndexing import AutomaticImageIndexing
automaticImageIndexing = AutomaticImageIndexing()

print(''.join(['Version : ', automaticImageIndexing.version()]))
print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

automaticImageIndexing.n_limite_directories = 20
automaticImageIndexing.n_limite_images = 0
print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
automaticImageIndexing.annotation_directory = 'annotation/'
automaticImageIndexing.picture_directory = 'images/'

automaticImageIndexing.read_picture_and_shift_feature_generation(False)

automaticImageIndexing.n_clusters = 100

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

#représenter 1 cluster pour voir l'homogénéité?
#=>représentation des descriptor du cluster

mega_histo = automaticImageIndexing.developBagOfVisualWord()#automaticImageIndexing.n_vocables)

#fonction d'application de developvoca.. pour une image (nb cluster variable)
#trouver l'optimal perf / justesse 
#tester par espèce 
# visuel
# montrer des correspondance

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)

print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)


picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

# class de travail
from Python.automaticImageIndexing import AutomaticImageIndexing
automaticImageIndexing = AutomaticImageIndexing()

print(''.join(['Version : ', automaticImageIndexing.version()]))
print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

automaticImageIndexing.n_limite_directories = 40
automaticImageIndexing.n_limite_images = 0
print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
automaticImageIndexing.annotation_directory = 'annotation/'
automaticImageIndexing.picture_directory = 'images/'

automaticImageIndexing.read_picture_and_shift_feature_generation(False)

automaticImageIndexing.n_clusters = 100

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

#représenter 1 cluster pour voir l'homogénéité?
#=>représentation des descriptor du cluster

mega_histo = automaticImageIndexing.developBagOfVisualWord()#automaticImageIndexing.n_vocables)

#fonction d'application de developvoca.. pour une image (nb cluster variable)
#trouver l'optimal perf / justesse 
#tester par espèce 
# visuel
# montrer des correspondance

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)

print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)


picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

# class de travail
from Python.automaticImageIndexing import AutomaticImageIndexing
automaticImageIndexing = AutomaticImageIndexing()

print(''.join(['Version : ', automaticImageIndexing.version()]))
print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

automaticImageIndexing.n_limite_directories = 80
automaticImageIndexing.n_limite_images = 0
print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
automaticImageIndexing.annotation_directory = 'annotation/'
automaticImageIndexing.picture_directory = 'images/'

automaticImageIndexing.read_picture_and_shift_feature_generation(False)

automaticImageIndexing.n_clusters = 100

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

#représenter 1 cluster pour voir l'homogénéité?
#=>représentation des descriptor du cluster

mega_histo = automaticImageIndexing.developBagOfVisualWord()#automaticImageIndexing.n_vocables)

#fonction d'application de developvoca.. pour une image (nb cluster variable)
#trouver l'optimal perf / justesse 
#tester par espèce 
# visuel
# montrer des correspondance

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)

print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)


picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

# class de travail
from Python.automaticImageIndexing import AutomaticImageIndexing
automaticImageIndexing = AutomaticImageIndexing()

print(''.join(['Version : ', automaticImageIndexing.version()]))
print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

automaticImageIndexing.n_limite_directories = 100
automaticImageIndexing.n_limite_images = 0
print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
automaticImageIndexing.annotation_directory = 'annotation/'
automaticImageIndexing.picture_directory = 'images/'

automaticImageIndexing.read_picture_and_shift_feature_generation(False)

automaticImageIndexing.n_clusters = 100

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

#représenter 1 cluster pour voir l'homogénéité?
#=>représentation des descriptor du cluster

mega_histo = automaticImageIndexing.developBagOfVisualWord()#automaticImageIndexing.n_vocables)

#fonction d'application de developvoca.. pour une image (nb cluster variable)
#trouver l'optimal perf / justesse 
#tester par espèce 
# visuel
# montrer des correspondance

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)

print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)


picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

# class de travail
from Python.automaticImageIndexing import AutomaticImageIndexing
automaticImageIndexing = AutomaticImageIndexing()

print(''.join(['Version : ', automaticImageIndexing.version()]))
print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

automaticImageIndexing.n_limite_directories = 0
automaticImageIndexing.n_limite_images = 0
print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
automaticImageIndexing.annotation_directory = 'annotation/'
automaticImageIndexing.picture_directory = 'images/'

automaticImageIndexing.read_picture_and_shift_feature_generation(False)

automaticImageIndexing.n_clusters = 100

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

#représenter 1 cluster pour voir l'homogénéité?
#=>représentation des descriptor du cluster

mega_histo = automaticImageIndexing.developBagOfVisualWord()#automaticImageIndexing.n_vocables)

#fonction d'application de developvoca.. pour une image (nb cluster variable)
#trouver l'optimal perf / justesse 
#tester par espèce 
# visuel
# montrer des correspondance

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)

print("cluster 0")
automaticImageIndexing.plot_descriptor_in_cluster(0)


picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)
