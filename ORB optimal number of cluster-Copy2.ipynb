# %%
import time
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

def generateModelV2(working_directory, 
                    number_directory=0, 
                    number_images=0,
                    #number_cluster=10,
                    descriptor_generator="SIFT", 
                    number_feature=200,
                    minimum_size_descriptor=20, 
                    #mode_affichage=""
                   ):
    start_time_model = time.time()

    # class de travail
    from Python.automaticImageIndexing import AutomaticImageIndexing
    automaticImageIndexing = AutomaticImageIndexing()

    print(''.join(['Version : ', automaticImageIndexing.version()]))
    print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

    automaticImageIndexing.n_limite_directories = number_directory
    automaticImageIndexing.n_limite_images = number_images
    print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
    print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

    automaticImageIndexing.working_directory = working_directory#'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
    automaticImageIndexing.annotation_directory = 'annotation/'
    automaticImageIndexing.picture_directory = 'images/'
    
    automaticImageIndexing.feature_generator = descriptor_generator
    print('Generator : %s' % automaticImageIndexing.feature_generator)
    automaticImageIndexing.n_feature = number_feature 
    print('Number of feature : %d' % automaticImageIndexing.n_feature)
    automaticImageIndexing.feature_size_min = minimum_size_descriptor
    print('Minimum feature size  %d' % automaticImageIndexing.feature_size_min)
    
    automaticImageIndexing.read_picture_and_feature_generation(with_sub_picture=True, descriptor_generator=descriptor_generator)
    print("Temps d execution apres parcour image + génération de features : %s secondes ---" % (time.time() - start_time_model))

    return automaticImageIndexing

def generateCluster(automaticImageIndexing, number_cluster=None, mode_affichage="", number_cluster_to_show=None):
    start_time_cluster = time.time()
    print("Generation des clusters pour %s descripteurs" % len(automaticImageIndexing.desc_list))
    if(number_cluster is None):
        number_cluster = int(10)
    automaticImageIndexing.n_clusters = number_cluster
    
    automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)
    print("Temps d execution apres Clustering : %s secondes ---" % (time.time() - start_time_cluster))
    mega_histo = automaticImageIndexing.developBagOfVisualWord()
    print("Temps d execution apres BOV : %s secondes ---" % (time.time() - start_time_cluster))
    automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)
    print("Temps d execution après plot BOV : %s secondes ---" % (time.time() - start_time_cluster))

    if number_cluster_to_show is None :
        number_cluster_to_show = int(number_cluster/2)
        
    if (mode_affichage == "subplot" or mode_affichage == "all"):
        print("affichage subplot des images liées au cluster %d" % number_cluster_to_show)
        automaticImageIndexing.plot_descriptor_in_cluster_subplot_V2(number_cluster_to_show)
        print("Temps d execution apres subplot : %s secondes ---" % (time.time() - start_time_cluster))
    
    if (mode_affichage == "individual_plot" or mode_affichage == "all"):
        print("affichage individuel des images liées au cluster %d" % number_cluster_to_show)
        automaticImageIndexing.plot_descriptor_in_cluster_individualplot(number_cluster_to_show)        
        print("Temps d execution apres individual_plot : %s secondes ---" % (time.time() - start_time_cluster))
    print("Temps d execution cluster : %s secondes ---" % (time.time() - start_time_cluster))

def showClusterPicture(automaticImageIndexing, mode_affichage="", number_cluster_to_show=None):
    start_time_showing = time.time()

    if automaticImageIndexing.n_clusters is None:
        print("Veuillez entrainer le model (& generer les cluster) ---")
    else:
        if number_cluster_to_show is None :
            number_cluster_to_show = int(automaticImageIndexing.n_clusters/2)

        if (mode_affichage == "subplot" or mode_affichage == "all"):
            print("affichage subplot des images liées au cluster %d" % number_cluster_to_show)
            automaticImageIndexing.plot_descriptor_in_cluster_subplot_V2(number_cluster_to_show)
            print("Temps d execution apres subplot : %s secondes ---" % (time.time() - start_time_showing))

        if (mode_affichage == "individual_plot" or mode_affichage == "all"):
            print("affichage individuel des images liées au cluster %d" % number_cluster_to_show)
            automaticImageIndexing.plot_descriptor_in_cluster_individualplot(number_cluster_to_show)        
            print("Temps d execution apres individual_plot : %s secondes ---" % (time.time() - start_time_showing))

# %%
#del model 

working_space = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
model = generateModelV2(
        working_directory=working_space,
        number_feature=75,
        number_directory=0, #all
        number_images=0,
        descriptor_generator="ORB",
        minimum_size_descriptor=100
    )

start = 500
stop = 100
step = -100

for nb_test in range(start, stop, step):
    print("-----------------------------------------------------------------------------------------")
    print("--------------------------------- start test cluster %s ---------------------------------" % str(nb_test))
    generateCluster(
        model,
        number_cluster=nb_test
    )
    showClusterPicture(
        model,
        mode_affichage="subplot",
        number_cluster_to_show=None
    )
    print("--------------------------------- stop test cluster %s ---------------------------------" % str(nb_test))
# Out:
# Version : 0.3
# Data directory : Data/
# Max Number of directory : 0
# Max Number of picture by directory : 0
# Generator : ORB
# Number of feature : 75
# Minimum feature size  100
# Computing Features for  n02085620-Chihuahua
# Computing Features for  n02085782-Japanese_spaniel
# Computing Features for  n02085936-Maltese_dog
# Computing Features for  n02086079-Pekinese
# Computing Features for  n02086240-Shih-Tzu
# Computing Features for  n02086646-Blenheim_spaniel
# Computing Features for  n02086910-papillon
# Computing Features for  n02087046-toy_terrier
# Computing Features for  n02087394-Rhodesian_ridgeback
# Computing Features for  n02088094-Afghan_hound
# Computing Features for  n02088238-basset
# Computing Features for  n02088364-beagle
# Computing Features for  n02088466-bloodhound
# Computing Features for  n02088632-bluetick
# Computing Features for  n02089078-black-and-tan_coonhound
# Computing Features for  n02089867-Walker_hound
# Computing Features for  n02089973-English_foxhound
# Computing Features for  n02090379-redbone
# Computing Features for  n02090622-borzoi
# Computing Features for  n02090721-Irish_wolfhound
# Computing Features for  n02091032-Italian_greyhound
# Computing Features for  n02091134-whippet
# Computing Features for  n02091244-Ibizan_hound
# Computing Features for  n02091467-Norwegian_elkhound
# Computing Features for  n02091635-otterhound
# Computing Features for  n02091831-Saluki
# Computing Features for  n02092002-Scottish_deerhound
# Computing Features for  n02092339-Weimaraner
# Computing Features for  n02093256-Staffordshire_bullterrier
# Computing Features for  n02093428-American_Staffordshire_terrier
# Computing Features for  n02093647-Bedlington_terrier
# Computing Features for  n02093754-Border_terrier
# Computing Features for  n02093859-Kerry_blue_terrier
# Computing Features for  n02093991-Irish_terrier
# Computing Features for  n02094114-Norfolk_terrier
# Computing Features for  n02094258-Norwich_terrier
# Computing Features for  n02094433-Yorkshire_terrier
# Computing Features for  n02095314-wire-haired_fox_terrier
# Computing Features for  n02095570-Lakeland_terrier
# Computing Features for  n02095889-Sealyham_terrier
# Computing Features for  n02096051-Airedale
# Computing Features for  n02096177-cairn
# Computing Features for  n02096294-Australian_terrier
# Computing Features for  n02096437-Dandie_Dinmont
# Computing Features for  n02096585-Boston_bull
# Computing Features for  n02097047-miniature_schnauzer
# Computing Features for  n02097130-giant_schnauzer
# Computing Features for  n02097209-standard_schnauzer
# Computing Features for  n02097298-Scotch_terrier
# Computing Features for  n02097474-Tibetan_terrier
# Computing Features for  n02097658-silky_terrier
# Computing Features for  n02098105-soft-coated_wheaten_terrier
# Computing Features for  n02098286-West_Highland_white_terrier
# Computing Features for  n02098413-Lhasa
# Computing Features for  n02099267-flat-coated_retriever
# Computing Features for  n02099429-curly-coated_retriever
# Computing Features for  n02099601-golden_retriever
# Computing Features for  n02099712-Labrador_retriever
# Computing Features for  n02099849-Chesapeake_Bay_retriever
# Computing Features for  n02100236-German_short-haired_pointer
# Computing Features for  n02100583-vizsla
# Computing Features for  n02100735-English_setter
# Computing Features for  n02100877-Irish_setter
# Computing Features for  n02101006-Gordon_setter
# Computing Features for  n02101388-Brittany_spaniel
# Computing Features for  n02101556-clumber
# Computing Features for  n02102040-English_springer
# Computing Features for  n02102177-Welsh_springer_spaniel
# Computing Features for  n02102318-cocker_spaniel
# Computing Features for  n02102480-Sussex_spaniel
# Computing Features for  n02102973-Irish_water_spaniel
# Computing Features for  n02104029-kuvasz
# Computing Features for  n02104365-schipperke
# Computing Features for  n02105056-groenendael
# Computing Features for  n02105162-malinois
# Computing Features for  n02105251-briard
# Computing Features for  n02105412-kelpie
# Computing Features for  n02105505-komondor
# Computing Features for  n02105641-Old_English_sheepdog
# Computing Features for  n02105855-Shetland_sheepdog
# Computing Features for  n02106030-collie
# Computing Features for  n02106166-Border_collie
# Computing Features for  n02106382-Bouvier_des_Flandres
# Computing Features for  n02106550-Rottweiler
# Computing Features for  n02106662-German_shepherd
# Computing Features for  n02107142-Doberman
# Computing Features for  n02107312-miniature_pinscher
# Computing Features for  n02107574-Greater_Swiss_Mountain_dog
# Computing Features for  n02107683-Bernese_mountain_dog
# Computing Features for  n02107908-Appenzeller
# Computing Features for  n02108000-EntleBucher
# Computing Features for  n02108089-boxer
# Computing Features for  n02108422-bull_mastiff
# Computing Features for  n02108551-Tibetan_mastiff
# Computing Features for  n02108915-French_bulldog
# Computing Features for  n02109047-Great_Dane
# Computing Features for  n02109525-Saint_Bernard
# Computing Features for  n02109961-Eskimo_dog
# Computing Features for  n02110063-malamute
# Computing Features for  n02110185-Siberian_husky
# Computing Features for  n02110627-affenpinscher
# Computing Features for  n02110806-basenji
# Computing Features for  n02110958-pug
# Computing Features for  n02111129-Leonberg
# Computing Features for  n02111277-Newfoundland
# Computing Features for  n02111500-Great_Pyrenees
# Computing Features for  n02111889-Samoyed
# Computing Features for  n02112018-Pomeranian
# Computing Features for  n02112137-chow
# Computing Features for  n02112350-keeshond
# Computing Features for  n02112706-Brabancon_griffon
# Computing Features for  n02113023-Pembroke
# Computing Features for  n02113186-Cardigan
# Computing Features for  n02113624-toy_poodle
# Computing Features for  n02113712-miniature_poodle
# Computing Features for  n02113799-standard_poodle
# Computing Features for  n02113978-Mexican_hairless
# Computing Features for  n02115641-dingo
# Computing Features for  n02115913-dhole
# Computing Features for  n02116738-African_hunting_dog
# Temps d execution apres parcour image + génération de features : 1447.95500016 secondes ---
# -----------------------------------------------------------------------------------------
# --------------------------------- start test cluster 500 ---------------------------------
# Generation des clusters pour 1465918 descripteurs

# %%
start = 1000
stop = 1000
step = -1000

for nb_test in range(start, stop, step):
    print("-----------------------------------------------------------------------------------------")
    print("--------------------------------- start test cluster %s ---------------------------------" % str(nb_test))
    generateCluster(
        model,
        number_cluster=nb_test
    )
    showClusterPicture(
        model,
        mode_affichage="subplot",
        number_cluster_to_show=None
    )
    print("--------------------------------- start test cluster %s ---------------------------------" % str(nb_test))
