# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, './')

# class de travail
from Python.automaticImageIndexing import AutomaticImageIndexing
automaticImageIndexing = AutomaticImageIndexing()

print(''.join(['Version : ', automaticImageIndexing.version()]))
print(''.join(['Data directory : ', automaticImageIndexing.data_directory]))

automaticImageIndexing.n_limite_directories = 1
automaticImageIndexing.n_limite_images = 1
print(''.join(['Max Number of directory : ', str(automaticImageIndexing.n_limite_directories)]))
print(''.join(['Max Number of picture by directory : ', str(automaticImageIndexing.n_limite_images)]))

automaticImageIndexing.working_directory = 'C:/Users/naru_/OneDrive/Documents/openclassroom/P7 traitement image/'
automaticImageIndexing.annotation_directory = 'annotation/'
automaticImageIndexing.picture_directory = 'images/'


automaticImageIndexing.read_picture_and_shift_feature_generation(with_sub_picture = True)
# Out:
# Version : 0.2
# Data directory : Data/
# Max Number of directory : 1
# Max Number of picture by directory : 1
# Computing Features for  n02085620-Chihuahua
# generate subpicture
# <generator object <genexpr> at 0x0000000010917F78>

# %%
print (automaticImageIndexing.kp_list[0].pt)
print (automaticImageIndexing.kp_list[0].size)
#print (automaticImageIndexing.desc_list)
#print (automaticImageIndexing.sub_picture_list[0])
#len(automaticImageIndexing.sub_picture_list#)
# Out:
# (227.2357177734375, 4.160679340362549)
# 2.03902363777

# %%
plt.imshow(automaticImageIndexing.desc_list[0].reshape(16,8), interpolation='none')
#plt.imshow(automaticImageIndexing.sub_picture_list[0], interpolation='none')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-208cb21587bd> in <module>()
# ----> 1 plt.imshow(automaticImageIndexing.desc_list[0].reshape(16,8), interpolation='none')
#       2 #plt.imshow(automaticImageIndexing.sub_picture_list[0], interpolation='none')
#
# IndexError: list index out of range

# %%
for img in automaticImageIndexing.desc_list :
    plt.imshow(img.reshape(16,8), interpolation='none')

# %%
from matplotlib import pyplot as plt
import numpy as np

nombre_desc = len(automaticImageIndexing.sub_picture_list)
nombre_colonne = 10
nombre_ligne = 1+ int(nombre_desc / nombre_colonne)+1
fig,axes = plt.subplots(nrows = nombre_ligne, ncols = nombre_colonne, figsize=(30,30))
#desc = automaticImageIndexing.desc_list[0].reshape(16,8)
#axes[0,0].imshow(desc) 
for ax in axes.flatten():
    ax.axis('off')
i=0
j=0

##edit this line to include your own image ids
for img in automaticImageIndexing.desc_list[0:2] :
    if i == nombre_colonne:
        j = j+1
        i = 1
    axes[j,i].imshow(img.reshape(16,8))
    i = i+1
plt.show()

# %%
methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
           'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
           'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']

# Fixing random state for reproducibility
automaticImageIndexing.np.random.seed(19680801)

grid = automaticImageIndexing.np.random.rand(16, 8)

fig, axs = automaticImageIndexing.plt.subplots(nrows=3, ncols=6, figsize=(9, 6),
                        subplot_kw={'xticks': [], 'yticks': []})

for ax, interp_method in zip(axs.flat, methods):
    ax.imshow(grid, interpolation=interp_method, cmap='viridis')
    ax.set_title(str(interp_method))

plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

nombre_desc = len(automaticImageIndexing.sub_picture_list)
nombre_colonne = 10
nombre_ligne = 1+ int(nombre_desc / nombre_colonne)+1
fig,axes = automaticImageIndexing.plt.subplots(nrows = nombre_ligne, ncols = nombre_colonne, figsize=(80,300),
                                              subplot_kw={'xticks': [], 'yticks': []})

i=0
j=0

##edit this line to include your own image ids
for img in automaticImageIndexing.desc_list[0:14] :
    if i == nombre_colonne:
        j = j+1
        i = 1
    axes[j,i].imshow(img.reshape(16,8), interpolation=None, cmap='viridis')
    i = i+1


plt.show()

# %%
def kp_to_feature(kp):
    """Convert KeyPoint to Feature."""
    x, y = kp.pt
    radius = kp.size / 2
    weight = radius * kp.response ** 2
    return Feature(
        label="self.LABEL",
        weight=weight,
        left=x - radius,
        top=y - radius,
        right=x + radius,
        bottom=y + radius
    ) * self._padding
print(automaticImageIndexing.kp_list[0:1])
print(automaticImageIndexing.kp_list[0].size)
kp_to_feature(automaticImageIndexing.kp_list[0])
# Out:
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-3abce1e62b09> in <module>()
#       1
#       2 print(automaticImageIndexing.kp_list[0:1])
# ----> 3 print(automaticImageIndexing.kp_list[0].size)
#       4 kp_to_feature(automaticImageIndexing.kp_list[0])
#
# IndexError: list index out of range

# %%
automaticImageIndexing.n_clusters = 5

automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)

mega_histo = automaticImageIndexing.developBagOfVisualWord()

automaticImageIndexing.plotHist(mega_histo, automaticImageIndexing.n_clusters, None)

mega_histo = automaticImageIndexing.standardize(mega_histo)
id_label = range(len(automaticImageIndexing.name_dict))
model_predition =automaticImageIndexing.train(mega_histo, id_label)


picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_7.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_199.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085620-Chihuahua\n02085620_2887.jpg',
    True
)

picture_histogramme = automaticImageIndexing.picture_in_BOV(
    r'C:\Users\naru_\OneDrive\Documents\openclassroom\P7 traitement image\images\n02085782-Japanese_spaniel\n02085782_518.jpg',
    True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-03c3b4763b9d> in <module>()
# ----> 1 automaticImageIndexing.n_clusters = 5
#       2
#       3 automaticImageIndexing.clusturing(automaticImageIndexing.n_clusters)
#       4
#       5 mega_histo = automaticImageIndexing.developBagOfVisualWord()
#
# NameError: name 'automaticImageIndexing' is not defined

# %%
automaticImageIndexing.kp_list[0]
#pour represeentation de feature invariant de sift
# voir si cv2.drawKeypoints ou autre
# Out:
# <KeyPoint 000000001476F300>

# %%
#afficher sub picture 
automaticImageIndexing.plot_picture_from_cluster(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e8e49eb3380f> in <module>()
#       1 #afficher sub picture
# ----> 2 automaticImageIndexing.plot_picture_from_cluster(1)
#
# C:\Users\naru_\Documents\Projet7_ImageIndex\Source\AutomaticImageIndexing\Python\automaticImageIndexing.py in plot_picture_from_cluster(self, num_cluster)
#     402                 if idx == num_cluster :
#     403                     self.plt.subplot(111)
# --> 404                     self.plt.imshow(image,cmap = 'gray')
#     405                     break
#     406         self.plt.title("Decriptor near the cluster")
#
# NameError: global name 'image' is not defined

# %%
num_cluster = 1
n_images = len(automaticImageIndexing.name_dict)
mega_histogram = automaticImageIndexing.np.array([automaticImageIndexing.np.zeros(automaticImageIndexing.n_clusters) for i in range(n_images)])
old_count = 0
for i in range(n_images):
    l = len(automaticImageIndexing.desc_list[i])
    for j in range(l):
        idx = automaticImageIndexing.kmeans_ret[old_count+j]
        if idx == num_cluster :
            automaticImageIndexing.plt.subplot(111)
            automaticImageIndexing.plt.imshow(automaticImageIndexing.desc_list[i],cmap = 'gray')
            break
automaticImageIndexing.plt.title("Decriptor near the cluster")
automaticImageIndexing.plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a11025461a13> in <module>()
#       9         if idx == num_cluster :
#      10             automaticImageIndexing.plt.subplot(111)
# ---> 11             automaticImageIndexing.plt.imshow(automaticImageIndexing.desc_list[i],cmap = 'gray')
#      12             break
#      13 automaticImageIndexing.plt.title("Decriptor near the cluster")
#
# C:\Users\naru_\Anaconda3\envs\opencv2\lib\site-packages\matplotlib\pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3208                         filternorm=filternorm, filterrad=filterrad,
#    3209                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3210                         **kwargs)
#    3211     finally:
# ...

# %%
print(type(automaticImageIndexing.np.asmatrix(automaticImageIndexing.desc_list[1])))
arr = automaticImageIndexing.np.asmatrix(automaticImageIndexing.desc_list[1])
arr = arr.astype(int)
print( automaticImageIndexing.np.asmatrix(arr))
print ([ 58,   6,   0,   0,   0,   0,   1,  46, 125,  10,   0,   0,   0,
         0,   0,  46, 119,  12,   0,   0,   0,   0,   1,  32,  56,  18,
         1,  25, 128,   2,   1,  10,  74,  28,   0,   0,   0,   0,   5,
        23,  99,  78,   0,   0,   0,   0,   0,   9, 142,  48,   0,   0,
         0,   0,   2,  46,  34,   3,   1,   6, 142,  22,   8,  43,  29,
         8,   0,   0,   0,   0,  19,  32, 122,  21,   0,   0,   0,   0,
         4,  30, 142,   8,   0,   0,   1,   1,   0,  50,  67,   0,   0,
        28, 142,  14,   1,  26,  33,   5,   0,   0,   0,   1,   7,  14,
        90,   3,   0,   0,   0,   1,  11,  47, 142,   0,   0,   1,   4,
         1,   0,  67,  56,   0,   0,  59, 142,   4,   0,  19])
automaticImageIndexing.plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
'''automaticImageIndexing.plt.imshow([[ 58,   6,   0,   0,   0,   0,   1,  46, 125,  10,   0,   0,   0,
         0,   0,  46, 119,  12,   0,   0,   0,   0,   1,  32,  56,  18,
         1,  25, 128,   2,   1,  10,  74,  28,   0,   0,   0,   0,   5,
        23,  99,  78,   0,   0,   0,   0,   0,   9, 142,  48,   0,   0,
         0,   0,   2,  46,  34,   3,   1,   6, 142,  22,   8,  43,  29,
         8,   0,   0,   0,   0,  19,  32, 122,  21,   0,   0,   0,   0,
         4,  30, 142,   8,   0,   0,   1,   1,   0,  50,  67,   0,   0,
        28, 142,  14,   1,  26,  33,   5,   0,   0,   0,   1,   7,  14,
        90,   3,   0,   0,   0,   1,  11,  47, 142,   0,   0,   1,   4,
         1,   0,  67,  56,   0,   0,  59, 142,   4,   0,  19]], cmap='gray', vmin=0, vmax=255)'''
[[1.,23,255],[255,23,1]]
# Out:
# <class 'numpy.matrix'>
# [[ 58   6   0   0   0   0   1  46 125  10   0   0   0   0   0  46 119  12
#     0   0   0   0   1  32  56  18   1  25 128   2   1  10  74  28   0   0
#     0   0   5  23  99  78   0   0   0   0   0   9 142  48   0   0   0   0
#     2  46  34   3   1   6 142  22   8  43  29   8   0   0   0   0  19  32
#   122  21   0   0   0   0   4  30 142   8   0   0   1   1   0  50  67   0
#     0  28 142  14   1  26  33   5   0   0   0   1   7  14  90   3   0   0
#     0   1  11  47 142   0   0   1   4   1   0  67  56   0   0  59 142   4
#     0  19]]
# ...

# %%
print(automaticImageIndexing.np.asmatrix(automaticImageIndexing.kmeans_ret[1]))

automaticImageIndexing.plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
# Out:
# [[4]]
